# %%
from math import sin,pi
import matplotlib.pyplot as plt
import numpy as np

# %%
xs=np.linspace(0,40,10000)
width_of_rectangle=xs[1]-xs[0]
area_of_rectangle=[width_of_rectangle*i**2 for i in xs]
plt.plot(xs,area_of_rectangle,"r",label="sinc(x)")
